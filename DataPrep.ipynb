# %%
import yfinance as yf
import pandas as pd
import yfinance as HistoricalPrices
import hvplot.pandas
from pathlib import Path

# %%
# Whats your ticker ?
ticker = 'ARKK'
# ticker = int(ticker)
# Where data starts and ends ?
start = '2020-03-01'
end = '2022-03-31'
arkk_etf = yf.download(ticker, start, end)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# Whats your ticker ?
ticker = 'SPY'
# ticker = int(ticker)
# Where data starts and ends ?
start = '2020-03-01'
end = '2022-03-31'
spy_etf = yf.download(ticker, start, end)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# Whats your ticker ?
ticker = 'FNGU'
# ticker = int(ticker)
# Where data starts and ends ?
start = '2020-03-01'
end = '2022-03-31'
fngu_etf = yf.download(ticker, start, end)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
arkk_etf = arkk_etf["Adj Close"].apply(lambda x: round(x,2)).rename("ARKK")
spy_etf = spy_etf["Adj Close"].apply(lambda x: round(x,2)).rename("SPY")
fngu_etf = fngu_etf["Adj Close"].apply(lambda x: round(x,2)).rename("FNGU")

# %%
etf_data = pd.concat([arkk_etf, spy_etf, fngu_etf], join="inner", axis = 1)

# %%
etf_data
# Out:
#              ARKK     SPY    FNGU
# Date
# 2020-03-02  52.79  294.65   80.15
# 2020-03-03  51.73  286.22   73.85
# 2020-03-04  53.49  298.25   80.57
# 2020-03-05  52.24  288.33   73.80
# 2020-03-06  50.87  283.57   68.17
# ...           ...     ...     ...
# 2022-03-24  66.40  444.68  236.00
# 2022-03-25  64.51  446.85  233.40
# 2022-03-28  67.06  450.03  247.00
# 2022-03-29  71.39  455.59  257.70
# 2022-03-30  68.68  452.78  247.50
#
# [526 rows x 3 columns]

# %%
etf_data.to_csv(Path("./Resources/Data/etf_data.csv"))

# %%
etf_data.tail(60)
# Out:
#              ARKK     SPY   FNGU
# Date
# 2022-01-04  92.69  469.93  380.4
# 2022-01-05  86.12  460.90  342.9
# 2022-01-06  85.58  460.47  349.1
# 2022-01-07  84.42  458.65  342.4
# 2022-01-10  84.64  458.08  344.2
# 2022-01-11  86.98  462.25  359.6
# 2022-01-12  84.56  463.50  372.7
# 2022-01-13  79.98  457.11  333.2
# 2022-01-14  80.24  457.30  342.5
# 2022-01-18  76.91  449.20  317.2
# 2022-01-19  75.75  444.54  308.3
# 2022-01-20  75.87  439.62  306.5
# 2022-01-21  71.52  430.99  257.4
# 2022-01-24  73.54  432.82  249.6
# 2022-01-25  70.80  427.53  233.7
# 2022-01-26  69.03  426.46  231.5
# 2022-01-27  66.33  424.36  220.4
# 2022-01-28  68.91  434.89  240.3
# 2022-01-31  75.43  442.73  282.1
# 2022-02-01  77.08  445.72  291.6
# 2022-02-02  73.14  450.05  290.7
# 2022-02-03  69.04  439.47  244.5
# 2022-02-04  72.75  441.54  258.5
# 2022-02-07  72.48  440.12  243.3
# 2022-02-08  72.39  443.74  257.1
# 2022-02-09  76.11  450.24  276.0
# 2022-02-10  73.76  442.15  259.0
# ...
